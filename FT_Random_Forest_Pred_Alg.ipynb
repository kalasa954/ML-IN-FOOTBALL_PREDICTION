# %%
#Stage 1: Importing the dataset and investigating it

# %%
import pandas as pd

# %%
matches=pd.read_csv('matches.csv',index_col=0)

# %%
matches
# Out:
#           date   time            comp         round  day venue result   gf  \
# 1   2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away      L  0.0
# 2   2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home      W  5.0
# 3   2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W  5.0
# 4   2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W  1.0
# 6   2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D  0.0
# ..         ...    ...             ...           ...  ...   ...    ...  ...
# 38  2021-05-02  19:15  Premier League  Matchweek 34  Sun  Away      L  0.0
# 39  2021-05-08  15:00  Premier League  Matchweek 35  Sat  Home      L  0.0
# 40  2021-05-16  19:00  Premier League  Matchweek 36  Sun  Away      W  1.0
# 41  2021-05-19  18:00  Premier League  Matchweek 37  Wed  Away      L  0.0
# 42  2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W  1.0
#
# ...

# %%
38*20*2
# Out:
# 1520

# %%
matches['round'].value_counts()
# Out:
# round
# Matchweek 1     39
# Matchweek 16    39
# Matchweek 34    39
# Matchweek 32    39
# Matchweek 31    39
# Matchweek 29    39
# Matchweek 28    39
# Matchweek 26    39
# Matchweek 25    39
# Matchweek 24    39
# Matchweek 23    39
# Matchweek 2     39
# Matchweek 19    39
# Matchweek 17    39
# Matchweek 20    39
# Matchweek 15    39
# Matchweek 5     39
# Matchweek 3     39
# Matchweek 13    39
# Matchweek 12    39
# Matchweek 4     39
# Matchweek 11    39
# Matchweek 10    39
# Matchweek 9     39
# Matchweek 8     39
# Matchweek 14    39
# Matchweek 7     39
# Matchweek 6     39
# Matchweek 30    37
# Matchweek 27    37
# Matchweek 22    37
# Matchweek 21    37
# Matchweek 18    37
# Matchweek 33    32
# Matchweek 35    20
# Matchweek 36    20
# Matchweek 37    20
# Matchweek 38    20
# Name: count, dtype: int64

# %%
matches['team'].value_counts()
# Out:
# team
# Southampton                 72
# Brighton and Hove Albion    72
# Manchester United           72
# West Ham United             72
# Newcastle United            72
# Burnley                     71
# Leeds United                71
# Crystal Palace              71
# Manchester City             71
# Wolverhampton Wanderers     71
# Tottenham Hotspur           71
# Arsenal                     71
# Leicester City              70
# Chelsea                     70
# Aston Villa                 70
# Everton                     70
# Liverpool                   38
# Fulham                      38
# West Bromwich Albion        38
# Sheffield United            38
# Brentford                   34
# Watford                     33
# Norwich City                33
# Name: count, dtype: int64

# %%
#Stage 2: Data Preparation

# %%
matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf              float64
# ga              float64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk              float64
# pkatt           float64
# season            int64
# team             object
# dtype: object

# %%
matches['date']=pd.to_datetime(matches['date'])

# %%
matches.dtypes
# Out:
# date            datetime64[ns]
# time                    object
# comp                    object
# round                   object
# day                     object
# venue                   object
# result                  object
# gf                     float64
# ga                     float64
# opponent                object
# xg                     float64
# xga                    float64
# poss                   float64
# attendance             float64
# captain                 object
# formation               object
# referee                 object
# match report            object
# notes                  float64
# sh                     float64
# sot                    float64
# dist                   float64
# fk                     float64
# pk                     float64
# pkatt                  float64
# season                   int64
# team                    object
# dtype: object

# %%
#Stage 3: Preparing the Predictors

# %%
matches['Venue_Code']=matches['venue'].astype('category').cat.codes

# %%
matches['Opponent_Code']=matches['opponent'].astype('category').cat.codes

# %%
matches['Day']=matches['date'].dt.dayofweek

# %%
matches
# Out:
#          date   time            comp         round  day venue result   gf  \
# 1  2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away      L  0.0
# 2  2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home      W  5.0
# 3  2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W  5.0
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W  1.0
# 6  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D  0.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 38 2021-05-02  19:15  Premier League  Matchweek 34  Sun  Away      L  0.0
# 39 2021-05-08  15:00  Premier League  Matchweek 35  Sat  Home      L  0.0
# 40 2021-05-16  19:00  Premier League  Matchweek 36  Sun  Away      W  1.0
# 41 2021-05-19  18:00  Premier League  Matchweek 37  Wed  Away      L  0.0
# 42 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W  1.0
#
#      ga        opponent  ...   sot  dist   fk   pk pkatt season  \
# ...

# %%
matches['Hour']=matches['time'].str.replace(":.+","",regex=True)

# %%
matches
# Out:
#          date   time            comp         round  day venue result   gf  \
# 1  2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away      L  0.0
# 2  2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home      W  5.0
# 3  2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W  5.0
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W  1.0
# 6  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D  0.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 38 2021-05-02  19:15  Premier League  Matchweek 34  Sun  Away      L  0.0
# 39 2021-05-08  15:00  Premier League  Matchweek 35  Sat  Home      L  0.0
# 40 2021-05-16  19:00  Premier League  Matchweek 36  Sun  Away      W  1.0
# 41 2021-05-19  18:00  Premier League  Matchweek 37  Wed  Away      L  0.0
# 42 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W  1.0
#
#      ga        opponent  ...  dist   fk   pk  pkatt season              team  \
# ...

# %%
matches['Target_Var']=(matches['result']=='W').astype('int')

# %%
matches
# Out:
#          date   time            comp         round  day venue result   gf  \
# 1  2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away      L  0.0
# 2  2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home      W  5.0
# 3  2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W  5.0
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W  1.0
# 6  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D  0.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 38 2021-05-02  19:15  Premier League  Matchweek 34  Sun  Away      L  0.0
# 39 2021-05-08  15:00  Premier League  Matchweek 35  Sat  Home      L  0.0
# 40 2021-05-16  19:00  Premier League  Matchweek 36  Sun  Away      W  1.0
# 41 2021-05-19  18:00  Premier League  Matchweek 37  Wed  Away      L  0.0
# 42 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W  1.0
#
#      ga        opponent  ...   fk   pk  pkatt  season              team  \
# ...

# %%
#Stage 4: Data Splitting & Random Forest Model Training

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf=RandomForestClassifier(n_estimators=50,min_samples_split=10,random_state=1)

# %%
train=matches[matches['date']<='2022-01-01']

# %%
train.shape
# Out:
# (1113, 32)

# %%
test=matches[matches['date']>'2022-01-01']

# %%
test.shape
# Out:
# (276, 32)

# %%
matches.dtypes
# Out:
# date             datetime64[ns]
# time                     object
# comp                     object
# round                    object
# day                      object
# venue                    object
# result                   object
# gf                      float64
# ga                      float64
# opponent                 object
# xg                      float64
# xga                     float64
# poss                    float64
# attendance              float64
# captain                  object
# formation                object
# referee                  object
# match report             object
# notes                   float64
# sh                      float64
# sot                     float64
# dist                    float64
# fk                      float64
# pk                      float64
# pkatt                   float64
# season                    int64
# team                     object
# Venue_Code                 int8
# Opponent_Code              int8
# ...

# %%
predictors=['Venue_Code','Opponent_Code','Day','Hour']

# %%
target=['Target_Var']

# %%
rf.fit(train[predictors],train[target].values.ravel())
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds=rf.predict(test[predictors])

# %%
test['Predictions']=preds
# Out:
# C:\Users\kalas\AppData\Local\Temp\ipykernel_11716\606484952.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Predictions']=preds

# %%
test
# Out:
#          date   time            comp         round  day venue result   gf  \
# 31 2022-01-15  12:30  Premier League  Matchweek 22  Sat  Home      W  1.0
# 32 2022-01-22  17:30  Premier League  Matchweek 23  Sat  Away      D  1.0
# 34 2022-02-09  19:45  Premier League  Matchweek 24  Wed  Home      W  2.0
# 35 2022-02-12  17:30  Premier League  Matchweek 25  Sat  Away      W  4.0
# 37 2022-02-19  17:30  Premier League  Matchweek 26  Sat  Home      L  2.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 33 2022-03-13  14:00  Premier League  Matchweek 29  Sun  Away      L  1.0
# 34 2022-04-02  15:00  Premier League  Matchweek 31  Sat  Away      D  0.0
# 35 2022-04-10  14:00  Premier League  Matchweek 32  Sun  Home      W  2.0
# 36 2022-04-16  15:00  Premier League  Matchweek 33  Sat  Away      L  2.0
# 37 2022-04-23  15:00  Premier League  Matchweek 34  Sat  Home      L  0.0
#
#      ga        opponent  ...   pk  pkatt  season             team Venue_Code  \
# ...

# %%
#Stage 5: RF Model Accuracy Calculation and Model Performance Improvement

# %%
from sklearn.metrics import accuracy_score

# %%
acc=accuracy_score(test['Target_Var'],test['Predictions'])

# %%
acc
# Out:
# 0.6086956521739131

# %%
combined=pd.DataFrame(dict(actual=test['Target_Var'],Predicted=test['Predictions']))

# %%
pd.crosstab(index=combined['actual'],columns=combined['Predicted'])
# Out:
# Predicted    0   1
# actual
# 0          147  25
# 1           83  21

# %%
21/(21+25)
# Out:
# 0.45652173913043476

# %%
from sklearn.metrics import precision_score

# %%
prec=precision_score(test['Target_Var'],test['Predictions'])

# %%
prec
# Out:
# 0.45652173913043476

# %%
(147+21)/(147+25+21+83)
# Out:
# 0.6086956521739131

# %%
#Stage 6: RF Model Performance Improvement using Rolling Averages

# %%
group_by_team=matches.groupby('team')

# %%
group=group_by_team.get_group('Manchester City')

# %%
group
# Out:
#          date   time            comp         round  day venue result   gf  \
# 1  2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away      L  0.0
# 2  2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home      W  5.0
# 3  2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W  5.0
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W  1.0
# 6  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D  0.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 54 2021-05-01  12:30  Premier League  Matchweek 34  Sat  Away      W  2.0
# 56 2021-05-08  17:30  Premier League  Matchweek 35  Sat  Home      L  1.0
# 57 2021-05-14  20:00  Premier League  Matchweek 36  Fri  Away      W  4.0
# 58 2021-05-18  19:00  Premier League  Matchweek 37  Tue  Away      L  2.0
# 59 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W  5.0
#
#      ga        opponent  ...   fk   pk  pkatt  season             team  \
# ...

# %%
def rolling_averages(group,cols,new_cols):
    group=group.sort_values("date")
    rolling_stats=group[cols].rolling(3,closed='left').mean()
    group[new_cols]=rolling_stats
    group=group.dropna(subset=new_cols)
    return group

# %%
matches.dtypes
# Out:
# date             datetime64[ns]
# time                     object
# comp                     object
# round                    object
# day                      object
# venue                    object
# result                   object
# gf                      float64
# ga                      float64
# opponent                 object
# xg                      float64
# xga                     float64
# poss                    float64
# attendance              float64
# captain                  object
# formation                object
# referee                  object
# match report             object
# notes                   float64
# sh                      float64
# sot                     float64
# dist                    float64
# fk                      float64
# pk                      float64
# pkatt                   float64
# season                    int64
# team                     object
# Venue_Code                 int8
# Opponent_Code              int8
# ...

# %%
cols=['gf','ga','sh','sot','dist','fk','pk','pkatt']

# %%
new_cols=[f'{c}_rolling' for c in cols]

# %%
new_cols
# Out:
# ['gf_rolling',
#  'ga_rolling',
#  'sh_rolling',
#  'sot_rolling',
#  'dist_rolling',
#  'fk_rolling',
#  'pk_rolling',
#  'pkatt_rolling']

# %%
rolling_averages(group,cols,new_cols)
# Out:
#          date   time            comp         round  day venue result   gf  \
# 5  2020-10-17  17:30  Premier League   Matchweek 5  Sat  Home      W  1.0
# 7  2020-10-24  12:30  Premier League   Matchweek 6  Sat  Away      D  1.0
# 9  2020-10-31  12:30  Premier League   Matchweek 7  Sat  Away      W  1.0
# 11 2020-11-08  16:30  Premier League   Matchweek 8  Sun  Home      D  1.0
# 12 2020-11-21  17:30  Premier League   Matchweek 9  Sat  Away      L  0.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 42 2022-03-14  20:00  Premier League  Matchweek 29  Mon  Away      D  0.0
# 44 2022-04-02  15:00  Premier League  Matchweek 31  Sat  Away      W  2.0
# 46 2022-04-10  16:30  Premier League  Matchweek 32  Sun  Home      D  2.0
# 49 2022-04-20  20:00  Premier League  Matchweek 30  Wed  Home      W  3.0
# 50 2022-04-23  15:00  Premier League  Matchweek 34  Sat  Home      W  5.0
#
#      ga        opponent  ...  Hour  Target_Var  gf_rolling  ga_rolling  \
# ...

# %%
matches_rolling=matches.groupby("team").apply(lambda x: rolling_averages(x,cols,new_cols))
# Out:
# C:\Users\kalas\AppData\Local\Temp\ipykernel_11716\4063446065.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   matches_rolling=matches.groupby("team").apply(lambda x: rolling_averages(x,cols,new_cols))

# %%
matches_rolling
# Out:
#                                  date   time            comp         round  \
# team
# Arsenal                 6  2020-10-04  14:00  Premier League   Matchweek 4
#                         7  2020-10-17  17:30  Premier League   Matchweek 5
#                         9  2020-10-25  19:15  Premier League   Matchweek 6
#                         11 2020-11-01  16:30  Premier League   Matchweek 7
#                         13 2020-11-08  19:15  Premier League   Matchweek 8
# ...                               ...    ...             ...           ...
# Wolverhampton Wanderers 32 2022-03-13  14:00  Premier League  Matchweek 29
#                         33 2022-03-18  20:00  Premier League  Matchweek 30
#                         34 2022-04-02  15:00  Premier League  Matchweek 31
#                         35 2022-04-08  20:00  Premier League  Matchweek 32
#                         36 2022-04-24  14:00  Premier League  Matchweek 34
#
# ...

# %%
matches_rolling=matches_rolling.droplevel('team')

# %%
matches_rolling
# Out:
#          date   time            comp         round  day venue result   gf  \
# 6  2020-10-04  14:00  Premier League   Matchweek 4  Sun  Home      W  2.0
# 7  2020-10-17  17:30  Premier League   Matchweek 5  Sat  Away      L  0.0
# 9  2020-10-25  19:15  Premier League   Matchweek 6  Sun  Home      L  0.0
# 11 2020-11-01  16:30  Premier League   Matchweek 7  Sun  Away      W  1.0
# 13 2020-11-08  19:15  Premier League   Matchweek 8  Sun  Home      L  0.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 32 2022-03-13  14:00  Premier League  Matchweek 29  Sun  Away      W  1.0
# 33 2022-03-18  20:00  Premier League  Matchweek 30  Fri  Home      L  2.0
# 34 2022-04-02  15:00  Premier League  Matchweek 31  Sat  Home      W  2.0
# 35 2022-04-08  20:00  Premier League  Matchweek 32  Fri  Away      L  0.0
# 36 2022-04-24  14:00  Premier League  Matchweek 34  Sun  Away      L  0.0
#
#      ga         opponent  ...  Hour  Target_Var  gf_rolling  ga_rolling  \
# ...

# %%
matches_rolling.index=range(matches_rolling.shape[0])

# %%
matches_rolling
# Out:
#            date   time            comp         round  day venue result   gf  \
# 0    2020-10-04  14:00  Premier League   Matchweek 4  Sun  Home      W  2.0
# 1    2020-10-17  17:30  Premier League   Matchweek 5  Sat  Away      L  0.0
# 2    2020-10-25  19:15  Premier League   Matchweek 6  Sun  Home      L  0.0
# 3    2020-11-01  16:30  Premier League   Matchweek 7  Sun  Away      W  1.0
# 4    2020-11-08  19:15  Premier League   Matchweek 8  Sun  Home      L  0.0
# ...         ...    ...             ...           ...  ...   ...    ...  ...
# 1312 2022-03-13  14:00  Premier League  Matchweek 29  Sun  Away      W  1.0
# 1313 2022-03-18  20:00  Premier League  Matchweek 30  Fri  Home      L  2.0
# 1314 2022-04-02  15:00  Premier League  Matchweek 31  Sat  Home      W  2.0
# 1315 2022-04-08  20:00  Premier League  Matchweek 32  Fri  Away      L  0.0
# 1316 2022-04-24  14:00  Premier League  Matchweek 34  Sun  Away      L  0.0
#
# ...

# %%
#Stage 7: RF model Retraining and Prediction Making

# %%
def make_predictions(data,predictors):
    train=data[data['date']<='2022-01-01']
    test=data[data['date']>'2022-01-01']
    rf.fit(train[predictors],train['Target_Var'])
    preds=rf.predict(test[predictors])
    combined=pd.DataFrame(dict(actual=test['Target_Var'],predicted=preds),index=test.index)
    precision=precision_score(test['Target_Var'],preds)
    return combined,precision

# %%
combined,precision=make_predictions(matches_rolling,predictors+new_cols)

# %%
precision
# Out:
# 0.5185185185185185

# %%
combined
# Out:
#       actual  predicted
# 55         0          1
# 56         1          0
# 57         1          0
# 58         1          1
# 59         1          1
# ...      ...        ...
# 1312       1          0
# 1313       0          0
# 1314       1          0
# 1315       0          1
# 1316       0          0
#
# [276 rows x 2 columns]

# %%
combined=combined.merge(matches_rolling[['date','team','opponent','result']],left_index=True,right_index=True)

# %%
combined
# Out:
#       actual  predicted       date                     team       opponent  \
# 55         0          1 2022-01-23                  Arsenal        Burnley
# 56         1          0 2022-02-10                  Arsenal         Wolves
# 57         1          0 2022-02-19                  Arsenal      Brentford
# 58         1          1 2022-02-24                  Arsenal         Wolves
# 59         1          1 2022-03-06                  Arsenal        Watford
# ...      ...        ...        ...                      ...            ...
# 1312       1          0 2022-03-13  Wolverhampton Wanderers        Everton
# 1313       0          0 2022-03-18  Wolverhampton Wanderers   Leeds United
# 1314       1          0 2022-04-02  Wolverhampton Wanderers    Aston Villa
# 1315       0          1 2022-04-08  Wolverhampton Wanderers  Newcastle Utd
# 1316       0          0 2022-04-24  Wolverhampton Wanderers        Burnley
#
#      result
# 55        D
# 56        W
# 57        W
# 58        W
# ...

# %%
class MissingDict(dict):
    __missing__=lambda self,key:key
map_values={
    "Manchester City":"Man City",
    "Manchester United":"Man Utd",
    "Wolverhampton Wanderers":"Wolves",
    "Brighton & Hove Albion":"Brighton",
    "Tottenham Hotspur":"Tottenham",
    "Newcastle United":"Newcastle Utd"
}
mapping=MissingDict(**map_values)

# %%
mapping['Arsenal']
# Out:
# 'Arsenal'

# %%
mapping['Manchester City']
# Out:
# 'Man City'

# %%
combined['new_team']=combined['team'].map(mapping)

# %%
combined
# Out:
#       actual  predicted       date                     team       opponent  \
# 55         0          1 2022-01-23                  Arsenal        Burnley
# 56         1          0 2022-02-10                  Arsenal         Wolves
# 57         1          0 2022-02-19                  Arsenal      Brentford
# 58         1          1 2022-02-24                  Arsenal         Wolves
# 59         1          1 2022-03-06                  Arsenal        Watford
# ...      ...        ...        ...                      ...            ...
# 1312       1          0 2022-03-13  Wolverhampton Wanderers        Everton
# 1313       0          0 2022-03-18  Wolverhampton Wanderers   Leeds United
# 1314       1          0 2022-04-02  Wolverhampton Wanderers    Aston Villa
# 1315       0          1 2022-04-08  Wolverhampton Wanderers  Newcastle Utd
# 1316       0          0 2022-04-24  Wolverhampton Wanderers        Burnley
#
#      result new_team
# 55        D  Arsenal
# 56        W  Arsenal
# ...

# %%
merged=combined.merge(combined,left_on=['date','new_team'],right_on=['date','opponent'])

# %% [markdown]
# merged

# %%
merged
# Out:
#      actual_x  predicted_x       date                   team_x     opponent_x  \
# 0           0            1 2022-01-23                  Arsenal        Burnley
# 1           1            0 2022-02-10                  Arsenal         Wolves
# 2           1            0 2022-02-19                  Arsenal      Brentford
# 3           1            1 2022-02-24                  Arsenal         Wolves
# 4           1            1 2022-03-06                  Arsenal        Watford
# ..        ...          ...        ...                      ...            ...
# 203         1            0 2022-03-13  Wolverhampton Wanderers        Everton
# 204         0            0 2022-03-18  Wolverhampton Wanderers   Leeds United
# 205         1            0 2022-04-02  Wolverhampton Wanderers    Aston Villa
# 206         0            1 2022-04-08  Wolverhampton Wanderers  Newcastle Utd
# 207         0            0 2022-04-24  Wolverhampton Wanderers        Burnley
#
# ...

# %%
merged[(merged['predicted_x']==1) & (merged['predicted_y']==0)]['actual_x'].value_counts()
# Out:
# actual_x
# 1    15
# 0    12
# Name: count, dtype: int64

# %%
15/27
# Out:
# 0.5555555555555556
